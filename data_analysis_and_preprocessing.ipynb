# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("processed_flipkart_mobile_phones.csv")

# %%
df = df.drop("Unnamed: 0", axis = 1)

# %%
df
# Out:
#                                           Product Name    Offer  \
# 0            REDMI Note 14 SE 5G (Crimson Art, 128 GB)  25% off
# 1         REDMI Note 14 SE 5G (Mystique White, 128 GB)  25% off
# 2                          Samsung Guru Music 2 B310ED  50% off
# 3                         POCO C71 (Cool Blue, 128 GB)  30% off
# 4            REDMI Note 14 SE 5G (Titan Black, 128 GB)  25% off
# ..                                                 ...      ...
# 163               POCO C75 5G (Silver Stardust, 64 GB)  30% off
# 164  vivo T4 Lite 5G Charger in the Box (Titanium G...  26% off
# 165             Motorola G85 5G (Viva Magenta, 128 GB)  23% off
# 166                       REDMI A5 (Just Black, 64 GB)  27% off
# 167         Samsung Galaxy F16 5G (Glam Green, 128 GB)  34% off
#
#                                    Camera  \
# 0    50MP + 8MP + 2MP | 20MP Front Camera
# 1    50MP + 8MP + 2MP | 20MP Front Camera
# 2                  0MP | 0MP Front Camera
# ...

# %%
df
# Out:
#                                           Product Name    Offer  \
# 0            REDMI Note 14 SE 5G (Crimson Art, 128 GB)  25% off
# 1         REDMI Note 14 SE 5G (Mystique White, 128 GB)  25% off
# 2                          Samsung Guru Music 2 B310ED  50% off
# 3                         POCO C71 (Cool Blue, 128 GB)  30% off
# 4            REDMI Note 14 SE 5G (Titan Black, 128 GB)  25% off
# ..                                                 ...      ...
# 163               POCO C75 5G (Silver Stardust, 64 GB)  30% off
# 164  vivo T4 Lite 5G Charger in the Box (Titanium G...  26% off
# 165             Motorola G85 5G (Viva Magenta, 128 GB)  23% off
# 166                       REDMI A5 (Just Black, 64 GB)  27% off
# 167         Samsung Galaxy F16 5G (Glam Green, 128 GB)  34% off
#
#                                    Camera  \
# 0    50MP + 8MP + 2MP | 20MP Front Camera
# 1    50MP + 8MP + 2MP | 20MP Front Camera
# 2                  0MP | 0MP Front Camera
# ...

# %%
df["Number of Reviews"] = splitted_cols[0].str.replace(",","").str.extract(r"(\d+)")
df["Number of Ratings"] = splitted_cols[1].str.replace(",","").str.extract(r"(\d+)")

# %%
df
# Out:
#                                           Product Name    Offer  \
# 0            REDMI Note 14 SE 5G (Crimson Art, 128 GB)  25% off
# 1         REDMI Note 14 SE 5G (Mystique White, 128 GB)  25% off
# 2                          Samsung Guru Music 2 B310ED  50% off
# 3                         POCO C71 (Cool Blue, 128 GB)  30% off
# 4            REDMI Note 14 SE 5G (Titan Black, 128 GB)  25% off
# ..                                                 ...      ...
# 163               POCO C75 5G (Silver Stardust, 64 GB)  30% off
# 164  vivo T4 Lite 5G Charger in the Box (Titanium G...  26% off
# 165             Motorola G85 5G (Viva Magenta, 128 GB)  23% off
# 166                       REDMI A5 (Just Black, 64 GB)  27% off
# 167         Samsung Galaxy F16 5G (Glam Green, 128 GB)  34% off
#
#                                    Camera  \
# 0    50MP + 8MP + 2MP | 20MP Front Camera
# 1    50MP + 8MP + 2MP | 20MP Front Camera
# 2                  0MP | 0MP Front Camera
# ...

# %%
final_df.to_csv("processed_flipkart_mobile_phones.csv")

# %%
final_df.shape
# Out:
# (168, 11)

# %% [markdown]
# # STORE INTO MONGODB

# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://localhost:27017/')

# %%
db = client["flipkart_database"]
collection = db["mobile_phones"]

# %%
data_dict = final_df.to_dict("records")

# %%
data_dict
# Out:
# [{'Product Name': 'REDMI Note 14 SE 5G (Crimson Art, 128 GB)',
#   'Offer': '25% off',
#   'Camera': '50MP + 8MP + 2MP | 20MP Front Camera',
#   'Memory': '6 GB RAM | 128 GB ROM',
#   'Battery': '5110 mAh Battery',
#   'Display': '16.94 cm (6.67 inch) Full HD+ Display',
#   'Ratings Number': nan,
#   'Sale Price': 14999,
#   'Actual Price': 19999,
#   'Number of Reviews': nan,
#   'Number of Ratings': nan},
#  {'Product Name': 'REDMI Note 14 SE 5G (Mystique White, 128 GB)',
#   'Offer': '25% off',
#   'Camera': '50MP + 8MP + 2MP | 20MP Front Camera',
#   'Memory': '6 GB RAM | 128 GB ROM',
#   'Battery': '5110 mAh Battery',
#   'Display': '16.94 cm (6.67 inch) Full HD+ Display',
#   'Ratings Number': nan,
#   'Sale Price': 14999,
#   'Actual Price': 19999,
#   'Number of Reviews': nan,
#   'Number of Ratings': nan},
#  {'Product Name': 'Samsung Guru Music 2 B310ED',
#   'Offer': '50% off',
#   'Camera': '0MP | 0MP Front Camera',
# ...

# %%
collection.insert_many(data_dict)
print("Dataframe inserted")
# Out:
# Dataframe inserted
