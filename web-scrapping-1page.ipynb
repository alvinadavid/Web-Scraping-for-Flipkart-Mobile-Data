# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
import requests

# %%
url = "https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
uClient = urlopen(url)
page_html = uClient.read()
uClient.close()

# %%
print(page_html)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.066267.css"/> <meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"
# ...

# %%
page_soup = BeautifulSoup(page_html, features='html')

# %%
print(page_soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
# SCRAP PRODUCT NAME

# %%
product_class_name = "KzDlHZ"

# %%
page_soup.find_all("div", {"class" : "KzDlHZ"})   #It returns a list of BeautifulSoup tag objects matching that condition.
# Out:
# [<div class="KzDlHZ">Samsung Galaxy F36 5G (Violet, 128 GB)</div>,
#  <div class="KzDlHZ">REDMI Note 14 SE 5G (Crimson Art, 128 GB)</div>,
#  <div class="KzDlHZ">POCO C71 (Cool Blue, 128 GB)</div>,
#  <div class="KzDlHZ">MOTOROLA g05 (Forest Green, 64 GB)</div>,
#  <div class="KzDlHZ">REDMI Note 14 SE 5G (Titan Black, 128 GB)</div>,
#  <div class="KzDlHZ">Samsung Galaxy F36 5G (Violet, 128 GB)</div>,
#  <div class="KzDlHZ">MOTOROLA g35 5G (Guava Red, 128 GB)</div>,
#  <div class="KzDlHZ">POCO C71 (Power Black, 128 GB)</div>,
#  <div class="KzDlHZ">Samsung Galaxy F05 (Twilight Blue, 64 GB)</div>,
#  <div class="KzDlHZ">vivo T4x 5G (Pronto Purple, 256 GB)</div>,
#  <div class="KzDlHZ">REDMI Note 14 SE 5G (Mystique White, 128 GB)</div>,
#  <div class="KzDlHZ">Samsung Galaxy F36 5G (Red, 128 GB)</div>,
#  <div class="KzDlHZ">REDMI A5 (Jaisalmer Gold, 128 GB)</div>,
#  <div class="KzDlHZ">Motorola g45 5G (Brilliant Green, 128 GB)</div>,
# ...

# %%
page_soup.find_all("div", {"class" : "KzDlHZ"})[1]
# Out:
# <div class="KzDlHZ">REDMI Note 14 SE 5G (Crimson Art, 128 GB)</div>

# %%
page_soup.find_all("div", {"class" : "KzDlHZ"})[0].text
# Out:
# 'Samsung Galaxy F36 5G (Violet, 128 GB)'

# %%
all_info_class_name = "tUxRFH"

# %%
containers = page_soup.find_all("div", {"class" : all_info_class_name})

# %%
containers[0]
# Out:
# <div class="tUxRFH"><a class="CGtC98" href="/samsung-galaxy-f36-5g-violet-128-gb/p/itm85ca200fd55e9?pid=MOBHDFVTH22ZAZXZ&amp;lid=LSTMOBHDFVTH22ZAZXZMFVJDX&amp;marketplace=FLIPKART&amp;q=mobiles&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_lNc-b78qRmDTvEml0z8Bkmae6DEz84nU2mrfjQ-nVjkZaVrFbSFgHW89-A7DeSbDQDHOGrmErLg6U7W94TAzQg%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=lx9w0bmj000000001754031021926&amp;qH=eb4af0bf07c16429" rel="noopener noreferrer" target="_blank"><div class="Otbq5D"><div class="yPq5Io"><div><div class="_4WELSP" style="height:200px;width:200px"><img alt="Samsung Galaxy F36 5G (Violet, 128 GB)" class="DByuf4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/1/1/v/-original-imahec9hs4znnd2y.jpeg?q=70"/></div></div></div><div class="qaR90o"><div class="A8uQAd"><span class="Lni97G"><label class="tJjCVx"><input class="vn9L2C" readonly="" type="checkbox"/><div class="XqNaEv"></div></label></s
# ...

# %%
len(containers)
# Out:
# 24

# %%
required_cols = ["product_name", "actual_price", "sale_price", "review and ratings", 
                 "offers", "camera", "processor", "memory", "battery" , "display"]

# %%
containers[0]
# Out:
# <div class="tUxRFH"><a class="CGtC98" href="/samsung-galaxy-f36-5g-violet-128-gb/p/itm85ca200fd55e9?pid=MOBHDFVTH22ZAZXZ&amp;lid=LSTMOBHDFVTH22ZAZXZMFVJDX&amp;marketplace=FLIPKART&amp;q=mobiles&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=en_lNc-b78qRmDTvEml0z8Bkmae6DEz84nU2mrfjQ-nVjkZaVrFbSFgHW89-A7DeSbDQDHOGrmErLg6U7W94TAzQg%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=lx9w0bmj000000001754031021926&amp;qH=eb4af0bf07c16429" rel="noopener noreferrer" target="_blank"><div class="Otbq5D"><div class="yPq5Io"><div><div class="_4WELSP" style="height:200px;width:200px"><img alt="Samsung Galaxy F36 5G (Violet, 128 GB)" class="DByuf4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/1/1/v/-original-imahec9hs4znnd2y.jpeg?q=70"/></div></div></div><div class="qaR90o"><div class="A8uQAd"><span class="Lni97G"><label class="tJjCVx"><input class="vn9L2C" readonly="" type="checkbox"/><div class="XqNaEv"></div></label></s
# ...

# %%
product_name = containers[0].find_all("div", {"class": "KzDlHZ"})[0].text #1

# %%
review_and_rating = containers[0].find_all("div", {"class": "_5OesEi"})[0].text #2

# %%
specifications = containers[0].find_all("div", {"class": "_6NESgJ"})[0] #3

# %%
memory_info = specifications.find_all('li')[0].text

# %%
memory_info
# Out:
# '6 GB RAM | 128 GB ROM | Expandable Upto 2 TB'

# %%
 specifications.find_all('li')[1].text #display
# Out:
# '17.02 cm (6.7 inch) Full HD+ Display'

# %%
 specifications.find_all('li')[2].text #camera info
# Out:
# '50MP + 8MP + 2MP | 13MP Front Camera'

# %%
 specifications.find_all('li')[3].text #battery info
# Out:
# '5000 mAh Battery'

# %%
 specifications.find_all('li')[4].text #processor info
# Out:
# 'Samsung Exynos 1380 Processor'

# %%
price = containers[0].find_all("div", {"class": "hl05eU"})[0].text   #actual price and sale price both in one place
price
# Out:
# '₹17,499₹22,99923% off'

# %%
containers[0].find_all("div", {"class": "UkUFwK"})[0].text  #offer
# Out:
# '23% off'

# %%
data_cols = ["Product Name", "Sale & Actual Price", "Reviews & Ratings", 
                 "Offers", "Camera", "Memory", "Battery" , "Display", "Rating Number"]

# %%
data = {}.fromkeys(data_cols, [])

# %%
data
# Out:
# {'Product Name': [],
#  'Sale & Actual Price': [],
#  'Reviews & Ratings': [],
#  'Offers': [],
#  'Camera': [],
#  'Memory': [],
#  'Battery': [],
#  'Display': [],
#  'Rating Number': []}

# %%
data = {"Product Name": [],
        "Sale & Actual Price": [],
        "Review & Ratings": [],
        "Offer": [],
        "Camera": [],
        "Memory": [],
        "Battery": [],
        "Display": [],
        "Ratings Number": []}



for contain in containers:
    product_name = contain.find_all("div", {"class": "KzDlHZ"})[0].text
    data["Product Name"].append(product_name)
    
    rr = contain.find_all("span", {"class": "Wphh3N"})
    if len(rr) == 0:
        review_and_rating = None
        rating_number = None
    else:
        review_and_rating = rr[0].text
        rating_number = contain.find_all("div", {"class": "XQDdHH"})[0].text
        
    data["Review & Ratings"].append(review_and_rating)
    data["Ratings Number"].append(rating_number)
    
    specifictations = contain.find_all("div", {"class": "_6NESgJ"})[0]
    
    data["Memory"].append(specifictations.find_all('li')[0].text)
    data["Display"].append(specifictations.find_all('li')[1].text)
    data["Camera"].append(specifictations.find_all('li')[2].text)
    data["Battery"].append(specifictations.find_all('li')[3].text)
    
    price = contain.find_all("div", {"class": "hl05eU"})[0].text
    data["Sale & Actual Price"].append(price)
    
    offer_list = contain.find_all("div", {"class": "UkUFwK"})
    if len(offer_list) == 0:
        data["Offer"].append("No Offer")
    else:
        data["Offer"].append(offer_list[0].text)

# %%
pd.DataFrame(data)
# Out:
#                                          Product Name    Sale & Actual Price  \
# 0              Samsung Galaxy F36 5G (Violet, 128 GB)  ₹17,499₹22,99923% off
# 1           REDMI Note 14 SE 5G (Crimson Art, 128 GB)  ₹14,999₹19,99925% off
# 2                        POCO C71 (Cool Blue, 128 GB)    ₹6,999₹9,99930% off
# 3                  MOTOROLA g05 (Forest Green, 64 GB)    ₹6,999₹9,99930% off
# 4           REDMI Note 14 SE 5G (Titan Black, 128 GB)  ₹14,999₹19,99925% off
# 5              Samsung Galaxy F36 5G (Violet, 128 GB)  ₹18,999₹24,49922% off
# 6                 MOTOROLA g35 5G (Guava Red, 128 GB)   ₹9,999₹12,49920% off
# 7                      POCO C71 (Power Black, 128 GB)    ₹6,999₹9,99930% off
# 8           Samsung Galaxy F05 (Twilight Blue, 64 GB)    ₹6,249₹9,99937% off
# 9                 vivo T4x 5G (Pronto Purple, 256 GB)  ₹16,999₹20,99919% off
# 10       REDMI Note 14 SE 5G (Mystique White, 128 GB)  ₹14,999₹19,99925% off
# ...
